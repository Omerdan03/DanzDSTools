# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Omerdan03/DanzDSTools/blob/master/Regression_tools.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.linspace(start=-50,stop=50, num=500)
noise = np.random.normal(0, 5, size=X.shape[0])
y = 5 * X + noise
y2 = 0.1 * X**3 +  X**2 - 3*X + 5 + 100*noise

# %% [markdown]
# Linear Regression

# %%
plt.plot(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X.reshape(-1,1), y)
y_pred = reg.predict(X.reshape(-1,1))
eq = f'y = {round(reg.coef_[0],2)}*x + {round(reg.intercept_,2)}'
plt.plot(X, y)
plt.plot(X, y_pred, label = eq)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Polynomial Regression

# %%
plt.plot(X, y2)
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso


n = 3
poly = PolynomialFeatures(n)
X_t = poly.fit_transform(X.reshape(-1,1))
reg = LinearRegression()
reg.fit(X_t, y2)
y2_pred = reg.predict(X_t)
plt.plot(X, y2)
plt.plot(X, y2_pred, label = eq)
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
# fitting and printing regression metrics

from sklearn.metrics import mean_squared_error, r2_score

def train_print_metrics(reg, X_train, y_train, X_test, y_test):
    print(type(reg).__name__)
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print(f'mean squared error {mean_squared_error(y_test, y_pred)}')
    print(f'R squard score {r2_score(y_test, y_pred)}')
